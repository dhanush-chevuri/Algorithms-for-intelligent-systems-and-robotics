# %% [markdown]
# # INSTALL FRAMEWORK

# %%
# !pip install ultralytics

# %% [markdown]
# # CLASSIFICATION

# %%
from ultralytics import YOLO
CLASSIFIER_ENGINE = YOLO("yolov8n-cls.pt")
RESULT = CLASSIFIER_ENGINE.predict(source="picture.jpg", save=True, save_txt=True)  # save predictions as labels
# Out:
# ...
# 100%|██████████| 5.30M/5.30M [01:22<00:00, 67.2kB/s]
# ...
# 100%|██████████| 755k/755k [00:03<00:00, 222kB/s]
# image 1/1 c:\Users\DELL\Desktop\New folder (2)\Neural networks\picture.jpg: 224x224 black_stork 0.39, lakeside 0.05, unicycle 0.04, little_blue_heron 0.03, whippet 0.03, 101.9ms
# Speed: 61.8ms preprocess, 101.9ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs\classify\predict
# 1 label saved to runs\classify\predict\labels

# %% [markdown]
# # OUTPUT

# %%
from IPython.display import Image
# Display the image
Image("runs/classify/predict/picture.jpg")
